# %%
import pandas as pd
data = {'Name':['Amit','Riya','John'], 'Marks':[85,90,78]}
df = pd.DataFrame(data)
df.to_csv("data.csv", index = False)

# %%
df=pd.read_csv("data.csv")
print(df.head(2))
# Out:
#    Name  Marks
# 0  Amit     85
# 1  Riya     90

# %%
df=pd.read_csv{"data."}

# %%
print()
print(df['Marks'])
print(df.iloc[0,1])
print()
print(df.loc[0,'Name'])

# %%
print(df[df['Marks'] > 80])
print(df.sort_values(by='Marks', ascending=False))

# %%
df['Grade'] = ['B', 'A', 'C']
print(df)

# %%
print()
grouped = df.groupby('Grade')['Marks'].mean()
print(grouped)

# %%
df2 = pd.DataFrame({'Nmae': ['A', 'B', 'C'], 'Marks' : [90, None, 70]})
print(df2.fillna(df2['Marks'].mean()))

# %%
print(df.describe()) # this method will give the statistical numbers
