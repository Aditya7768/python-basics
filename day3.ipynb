# %%
sum=lambda a,b : a+b
print(sum(10,5))

# %%
square =lambda a:a**2
print (square(5))

# %%
num= lambda a:"even" if a%2==0 else "odd"

# %%
num=lambda x :x%2
if num(10)==0:
    print("even")
else:    print("odd")

# %%
distances =[40,55,30,70]
emission_factor=0.21


emission=list(map(lambda x: x*emission_factor, distances))
print(emission)

# %%
#identify households exceeding 300 units 

units =[210,320,280,410,260]
emission = list(filter(lambda x: x > 300, units))
print(emission)

# %%
#compute efficiency = output /max_output

generation =[120,150,180,200]
max_value =max(generation)
efficiency = list(map(lambda x: x/max_value ,generation))
print (efficiency)

# %%
cities = [
    {"City": "Delhi", "AQI": 320},
    {"City": "Mumbai", "AQI": 185},
    {"City": "Pune", "AQI": 140}
]

sorted_cities = sorted(cities, key=lambda x: x["AQI"], reverse=True)

print(sorted_cities)
